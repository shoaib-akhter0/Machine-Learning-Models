# %% [markdown]
# # **Python - Variable Names**
#
# **Rules for Python variables:**
#
# A variable name must start with a letter or the underscore character
#
# A variable name cannot start with a number
#
# A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
#
# Variable names are case-sensitive (age, Age and AGE are three different variables)
#
# A variable name cannot be any of the Python keywords.

# %%
# Line 1: Create a variable and store name (string)
name = "Ali"

print("Name:", name)
# Out:
# Name: Ali

# %%
# Line 2: Create a variable and store age (integer)
age = 20
print("Age:", age)
# Out:
# Age: 20

# %%
# Line 3: Create a variable and store height (float)
height = 5.8
print("Height:", height)
# Out:
# Height: 5.8

# %%
# Line 4: Create a variable and store True/False (boolean)
is_student = True
print("Is Student:", is_student)
# Out:
# Is Student: True

# %%
x = "Python is awesome"
print(x)
# Out:
# Python is awesome

# %%
x = "Python"
y = "is"
z = "awesome"
print(x, y, z)
# Out:
# Python is awesome

# %%
x = "Python "
y = "is "
z = "awesome"
print(x + y + z)
# Out:
# Python is awesome

# %%
x = 5
y = 10
print(x + y)
# Out:
# 15

# %%
x = 5
y = "John"
print(x, y)
# Out:
# 5 John

# %%
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry
